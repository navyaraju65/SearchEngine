# %%
import requests
from bs4 import BeautifulSoup

START_URL = 'https://pureportal.coventry.ac.uk/en/publications'

def crawl(url):
    response = requests.get(url)
    if response.status_code == 200:
        return BeautifulSoup(response.content, "html.parser")
    return None

def extract_publication_data(soup):
    data = []
    result_containers = soup.find_all("div", class_="result-container")
    for d in result_containers:
        title = d.find("h3", class_="title").text.strip()
        authors_element = d.find("a", class_="link person",)
        authors_element = d.find("a", class_="link person",)
        authors = authors_element.text.strip() if authors_element else "Unknown"
        # Extract the second author's name
        second_author_element = d.find("a", class_="link person", string=lambda text: text and " (ed.)" in text)
        second_author = second_author_element.text.strip() if second_author_element else "Unknown"
        year_element = d.find("span", class_="date")
        year = year_element.text.strip() if year_element else "Unknown"
        profile_link_element = d.find('a', class_='link person')
        profile =  profile_link_element['href'] if profile_link_element else "Unknown"
        publication_page_link = d.find("a", class_="link")
        publication_page =  publication_page_link["href"] if publication_page_link else "Unknown"

        data.append({
            "Title": title,
            "Year": year,
            "Author": authors,
            "Second Author": second_author,
            "Publication page link": publication_page,
            "Author profile link": profile
        })
    return data

def search_cgl_publications(query):
    search_url = START_URL + f'?search={query.replace(" ", "+")}&organisations=coventry-university%2Fcentre-for-global-learning'
    soup = crawl(search_url)
    if soup:
        return extract_publication_data(soup)
    return []

def display_results(results):
    if results:
        for idx, result in enumerate(results, start=1):
            print(f"{idx}  Author: {result['Author']}, {result['Second Author']}")
            print(f"   publication Year: {result['Year']}")
            print(f"   title: {result['Title']}")
            print(f"   Publication page link: {result['Publication page link']}")
            print(f"   Author profile link: {result['Author profile link']}")
            print()
    else:
        print("No results found.")

def main():
    while True:
        query = input("Enter your search query (or type 'exit' to quit): ").strip().lower()
        if query == 'exit':
            break

        print(f"Searching for publications related to '{query}'...")
        results = search_cgl_publications(query)
        display_results(results)

if __name__ == "__main__":
    main()
# Out:
# Enter your search query (or type 'exit' to quit):
# Searching for publications related to ''...
# 1  Author: Alami Fariman, M. (ed.), Alami Fariman, M. (ed.)
#    publication Year: 2025
#    title: City, Public Space and Body: The Embodied Experience of Urban Life
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/city-public-space-and-body-the-embodied-experience-of-urban-life
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/mahsa-alami-fariman
#
# 2  Author: Knowles, T., Unknown
#    publication Year: 2024
#    title: Bletchley Park in Myth and Memory
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/bletchley-park-in-myth-and-memory
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/thomas-knowles
#
# 3  Author: Reid, D. R., Unknown
#    publication Year: 2024
#    title: Indigenous Peoples and the UN Sustainable Development Goals in South America: The Case for Change
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/indigenous-peoples-and-the-un-sustainable-development-goals-in-so
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/darren-reid
#
# 4  Author: Stroud, A., Unknown
#    publication Year: 9 Feb 2024
#    title: Jezero
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/jezero
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/allen-stroud
#
# 5  Author: Stroud, A., Unknown
#    publication Year: 12 Jan 2024
#    title: Luna
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/luna
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/allen-stroud
#
# 6  Author: Lovell, K. (ed.), Lovell, K. (ed.)
#    publication Year: 21 Aug 2023
#    title: #RecordCovid19: Historicizing Experiences of the Pandemic
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/recordcovid19-historicizing-experiences-of-the-pandemic
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/kristopher-lovell
#
# 7  Author: Liu, M., Unknown
#    publication Year: 25 Mar 2023
#    title: 10 Years on with French Arbitration Law Reform: Does the Judicial Control Frustrate or Facilitate the Enforcement of Arbitral Awards?
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/10-years-on-with-french-arbitration-law-reform-does-the-judicial-
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/margaret-liu
#
# 8  Author: Carew, R., Unknown
#    publication Year: Jun 2023
#    title: 3D forensic science: An introductory statement from the members of the Forensic Capability Network (FCN) Visual Technologies Research Group (VTRG)
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/3d-forensic-science-an-introductory-statement-from-the-members-of
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/rachael-carew
#
# 9  Author: Skeik, O., Unknown
#    publication Year: 28 Feb 2023
#    title: 6D Pose Estimation for Precision Assembly
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/6d-pose-estimation-for-precision-assembly
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/ola-skeik
#
# 10  Author: Alsaid, L., Unknown
#    publication Year: 9 Jun 2023
#    title: ABC as a multi-lens sustainability reporting system in smart cities
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/abc-as-a-multi-lens-sustainability-reporting-system-in-smart-citi
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/loai-alsaid
#
# 11  Author: Harris, D., Unknown
#    publication Year: 1 Jun 2023
#    title: Accuracy and Similarity of Team Situation Awareness in Simulated Air Combat
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/accuracy-and-similarity-of-team-situation-awareness-in-simulated-
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/donald-harris
#
# 12  Author: Enebuse, I., Unknown
#    publication Year: 17 Apr 2023
#    title: Accuracy Assessment of Hand-Eye Calibration Techniques in Uncertain Environments for Vision Guided Robots
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/accuracy-assessment-of-hand-eye-calibration-techniques-in-uncerta
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/ikenna-stanley-enebuse
#
# 13  Author: Mambazhasseri Divakaran, A., Unknown
#    publication Year: 11 Apr 2023
#    title: A CFD-Based Numerical Evaluation, Assessment and Optimization of Conjugate Heat Transfer for Aerodynamic Cooling of a Wheel-Hub-Motors in Micro-Mobility Vehicles
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/a-cfd-based-numerical-evaluation-assessment-and-optimization-of-c
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/arun-mambazhasseri-divakaran
#
# 14  Author: Huang, Y., Unknown
#    publication Year: 14 Feb 2023
#    title: A closer look at high-energy X-ray-induced bubble formation during soft tissue imaging
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/a-closer-look-at-high-energy-x-ray-induced-bubble-formation-durin
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/yuze-huang
#
# 15  Author: McGurk, C., Unknown
#    publication Year: 12 Jan 2023
#    title: A comparative analysis of moving average filter and Kalman filter for large diesel engine test cell back-pressure control
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/a-comparative-analysis-of-moving-average-filter-and-kalman-filter
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/colin-mcgurk
#
# 16  Author: Fitzpatrick, M. E., Unknown
#    publication Year: 19 Jun 2023
#    title: A comparison of machine learning methods to classify radioactive elements using prompt-gamma-ray neutron activation data
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/a-comparison-of-machine-learning-methods-to-classify-radioactive-
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/michael-fitzpatrick
#
# 17  Author: Bennett, J., Unknown
#    publication Year: Jun 2023
#    title: A conceptual framework for understanding ecosystem trade-offs and synergies, in communal rangeland systems.
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/a-conceptual-framework-for-understanding-ecosystem-trade-offs-and
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/james-bennett
#
# 18  Author: Huang, Y., Unknown
#    publication Year: 25 May 2023
#    title: Additive manufacturing enabled synergetic strengthening of bimodal reinforcing particles for aluminum matrix composites
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/additive-manufacturing-enabled-synergetic-strengthening-of-bimoda
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/yuze-huang
#
# 19  Author: Zhang, C., Unknown
#    publication Year: 14 Jun 2023
#    title: A deep learning approach for state-of-health estimation of lithium-ion batteries based on differential thermal voltammetry and attention mechanism
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/a-deep-learning-approach-for-state-of-health-estimation-of-lithiu
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/cheng-zhang
#
# 20  Author: Christopoulos, S., Unknown
#    publication Year: 10 Jul 2023
#    title: A density functional theory study of the CiN and the CiNOi complexes in silicon
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/a-density-functional-theory-study-of-the-cin-and-the-cinoi-comple
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/stavros-christopoulos
#
# 21  Author: Yang, Q., Unknown
#    publication Year: Jan 2023
#    title: A Dynamic Heat/Power Decoupling Strategy for the Fuel Cell CHP in the Community Energy System: A Real Case Study in South of China
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/a-dynamic-heatpower-decoupling-strategy-for-the-fuel-cell-chp-in-
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/qingqing-yang
#
# 22  Author: Postlethwaite, R. D., Unknown
#    publication Year: 1 Apr 2023
#    title: Aerobically trained older adults show impaired resting, but preserved exercise-induced circulating progenitor cell count, which was not improved by sprint interval training
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/aerobically-trained-older-adults-show-impaired-resting-but-preser
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/ruth-postlethwaite
#
# 23  Author: Aune, K., Unknown
#    publication Year: 2 Feb 2023
#    title: Aesthetic labor in religious contexts: Women encountering modest dress in the workplace in the UK and Saudi Arabia
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/aesthetic-labor-in-religious-contexts-women-encountering-modest-d
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/kristin-aune
#
# 24  Author: Anbalagan, A., Unknown
#    publication Year: Jan 2023
#    title: A FEA simulation study on impeller failures considering various materials
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/a-fea-simulation-study-on-impeller-failures-considering-various-m
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/a-anbalagan
#
# 25  Author: Zhang, X., Unknown
#    publication Year: 22 Apr 2023
#    title: A Finite Element Model for Predicting the Static Strength of a Composite Hybrid Joint with Reinforcement Pins
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/a-finite-element-model-for-predicting-the-static-strength-of-a-co
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/xiang-zhang
#
# 26  Author: Unknown, Unknown
#    publication Year: 5 Jun 2023
#    title: Afterword
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/afterword
#    Author profile link: Unknown
#
# 27  Author: Zheng, D., Unknown
#    publication Year: 5 Jun 2023
#    title: Age-Related Changes in Blood Volume Pulse Wave at Fingers and Ears
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/age-related-changes-in-blood-volume-pulse-wave-at-fingers-and-ear
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/dingchang-zheng-2
#
# 28  Author: Duncan, M., Unknown
#    publication Year: 18 Apr 2023
#    title: Age-Related Differences in Trunk Kinematics and Interplanar Decoupling with the Pelvis during Gait in Healthy Older versus Younger Men
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/age-related-differences-in-trunk-kinematics-and-interplanar-decou
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/michael-duncan
#
# 29  Author: Yitbarek, T. W., Unknown
#    publication Year: Jul 2023
#    title: A governance framework for the design and evaluation of tree planting schemes
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/a-governance-framework-for-the-design-and-evaluation-of-tree-plan
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/yitbarek-weldesemaet
#
# 30  Author: Tallis, J., Unknown
#    publication Year: 13 Jun 2023
#    title: Agreement between Force Platform and Smartphone Application-Derived Measures of Vertical Jump Height in Youth Grassroots Soccer Players
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/agreement-between-force-platform-and-smartphone-application-deriv
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/jason-tallis
#
# 31  Author: Félix, G. F., Unknown
#    publication Year: 31 May 2023
#    title: Agroecology and food sovereignty in the Caribbean: Insights from Cuba, Puerto Rico, and Sint Maarten
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/agroecology-and-food-sovereignty-in-the-caribbean-insights-from-c
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/georges-felix
#
# 32  Author: Haas, O., Unknown
#    publication Year: 20 Jun 2023
#    title: A Hierarchical Economic Model Predictive Controller That Exploits Look-Ahead Information of Roads to Boost Engine Performance
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/a-hierarchical-economic-model-predictive-controller-that-exploits
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/olivier-haas
#
# 33  Author: Hu, P., Unknown
#    publication Year: 2023
#    title: AlignBodyNet: Deep Learning-based Alignment of Non-overlapping Partial Body Point Clouds from a Single Depth Camera
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/alignbodynet-deep-learning-based-alignment-of-non-overlapping-par
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/pengpeng-hu
#
# 34  Author: Latvyte, E., Unknown
#    publication Year: 1 Jun 2023
#    title: A low-temperature ammonia electrolyser for wastewater treatment and hydrogen production
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/a-low-temperature-ammonia-electrolyser-for-wastewater-treatment-a
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/egle-latvyte
#
# 35  Author: Maravic da Silva, K., Unknown
#    publication Year: 25 May 2023
#    title: Alpha-Stim AID cranial electrotherapy stimulation (CES) anxiety treatment: anxiety, depression, and health-related quality-of-life outcomes in primary healthcare social prescribing services
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/alpha-stim-aid-cranial-electrotherapy-stimulation-ces-anxiety-tre
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/ksenija-maravic-da-silva
#
# 36  Author: Bastien, C., Unknown
#    publication Year: 30 Mar 2023
#    title: A machine learning based optimisation method to evaluate the crushing behaviours of square tubes with rectangular-hole-type initiators
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/a-machine-learning-based-optimisation-method-to-evaluate-the-crus
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/christophe-bastien
#
# 37  Author: Richards, B., Unknown
#    publication Year: 28 Jun 2023
#    title: A Method for Improving the Performance of Ensemble Neural Networks by Introducing Randomization into Their Training Data
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/a-method-for-improving-the-performance-of-ensemble-neural-network
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/bryn-geoffrey-roddick-richards
#
# 38  Author: Bastien, C., Unknown
#    publication Year: 15 Apr 2023
#    title: A methodology to investigate and optimise the crashworthiness response of foam-filled twelve right angles thin-walled structures under axial impact
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/a-methodology-to-investigate-and-optimise-the-crashworthiness-res
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/christophe-bastien
#
# 39  Author: Pryce-Miller, M., Unknown
#    publication Year: 20 Jan 2023
#    title: A mixed-methods evaluation of unconscious racial bias training for NHS senior practitioners to improve the experiences of racially minoritised students
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/a-mixed-methods-evaluation-of-unconscious-racial-bias-training-fo
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/maxine-pryce-miller
#
# 40  Author: Sereez, M., Unknown
#    publication Year: 29 Mar 2023
#    title: A modified dual time integration technique for aerodynamic quasi-static and dynamic stall hysteresis
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/a-modified-dual-time-integration-technique-for-aerodynamic-quasi-
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/mohamed-sereez
#
# 41  Author: Unknown, Unknown
#    publication Year: 30 May 2023
#    title: Analysis of national physical activity and sedentary behaviour policies in China
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/analysis-of-national-physical-activity-and-sedentary-behaviour-po
#    Author profile link: Unknown
#
# 42  Author: Liaghat, G., Unknown
#    publication Year: Jan 2023
#    title: An analytical investigation on the crushing behavior of thin-walled tubes filled with a foam with strain hardening region
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/an-analytical-investigation-on-the-crushing-behavior-of-thin-wall
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/gholamhossein-liaghat
#
# 43  Author: Sadri, H., Unknown
#    publication Year: 7 Feb 2023
#    title: A narrative from the right to the city in Iran: the theoretical–practical continuum of urban development in Bandar Abbas
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/a-narrative-from-the-right-to-the-city-in-iran-the-theoreticalpra
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/hos-adri-sadri
#
# 44  Author: Unknown, Unknown
#    publication Year: May 2023
#    title: A narrative review of the functional components of human breast milk and their potential to modulate the gut microbiome, the consideration of maternal and child characteristics, and confounders of breastfeeding, and their impact on risk of obesity later in life
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/a-narrative-review-of-the-functional-components-of-human-breast-m
#    Author profile link: Unknown
#
# 45  Author: Ugwueze, O., Unknown
#    publication Year: 21 Mar 2023
#    title: An Efficient and Robust Sizing Method for eVTOL Aircraft Configurations in Conceptual Design
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/an-efficient-and-robust-sizing-method-for-evtol-aircraft-configur
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/osita-nnanna-ugwueze
#
# 46  Author: Carew, R., Unknown
#    publication Year: Jul 2023
#    title: An ethical framework for the creation and use of 3D printed human remains in crime reconstruction
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/an-ethical-framework-for-the-creation-and-use-of-3d-printed-human
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/rachael-carew
#
# 47  Author: Saidani, M., Unknown
#    publication Year: 25 Mar 2023
#    title: A new method for determining the effective length factor of columns in partially braced frames on elastic supports
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/a-new-method-for-determining-the-effective-length-factor-of-colum
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/messaoud-saidani
#
# 48  Author: Pearce, N. F., Unknown
#    publication Year: Sept 2023
#    title: A new synergistic model for simulating exercise incorporating control mechanisms at cellular and organ scales
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/a-new-synergistic-model-for-simulating-exercise-incorporating-con
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/nicholas-pearce
#
# 49  Author: Bashiri, M., Unknown
#    publication Year: 16 Nov 2023
#    title: An exact criterion space search algorithm for a bi-objective blood collection problem
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/an-exact-criterion-space-search-algorithm-for-a-bi-objective-bloo
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/mahdi-bashiri
#
# 50  Author: Pay, M. L., Unknown
#    publication Year: 9 Jan 2023
#    title: An Extended Plant Circadian Clock Model for Characterising Flowering Time under Different Light Quality Conditions
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/an-extended-plant-circadian-clock-model-for-characterising-flower
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/miao-lin-pay
# Enter your search query (or type 'exit' to quit):  Alami Fariman, M.
# Searching for publications related to 'alami fariman, m.'...
# 1  Author: Alami Fariman, M., Unknown
#    publication Year: 15 Oct 2022
#    title: Embodied Openness
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/embodied-openness
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/mahsa-alami-fariman
#
# 2  Author: Alami Fariman, M., Unknown
#    publication Year: 4 Oct 2022
#    title: Medicalising Uprightness: Do medical advances make us long to be taller?
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/medicalising-uprightness-do-medical-advances-make-us-long-to-be-t
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/mahsa-alami-fariman
#
# 3  Author: Alami Fariman, M. (ed.), Alami Fariman, M. (ed.)
#    publication Year: 2025
#    title: City, Public Space and Body: The Embodied Experience of Urban Life
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/city-public-space-and-body-the-embodied-experience-of-urban-life
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/mahsa-alami-fariman
#
# 4  Author: Alami Fariman, M., Unknown
#    publication Year: 17 May 2020
#    title: Right to the Public Space; The Case of Tehran
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/right-to-the-public-space-the-case-of-tehran
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/mahsa-alami-fariman
#
# 5  Author: Alami Fariman, M., Unknown
#    publication Year: 6 Jul 2022
#    title: Closedness and openness in Tehran; a feminist critique of Sennett
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/closedness-and-openness-in-tehran-a-feminist-critique-of-sennett
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/mahsa-alami-fariman
#
# 6  Author: Alami Fariman, M., Unknown
#    publication Year: 28 Sept 2022
#    title: Excitement, Courage and Fear The Affective Dimension of Ethnographic Fieldwork at Night in Tehran
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/excitement-courage-and-fear-the-affective-dimension-of-ethnograph
#    Author profile link: https://pureportal.coventry.ac.uk/en/persons/mahsa-alami-fariman
# Enter your search query (or type 'exit' to quit):  Yang, Q., Unknown
# Searching for publications related to 'yang, q., unknown'...
# 1  Author: Unknown, Unknown
#    publication Year: Mar 2022
#    title: Lifestyle factors and fetal and childhood origins of type 2 diabetes: A prospective study of Chinese and European adults
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/lifestyle-factors-and-fetal-and-childhood-origins-of-type-2-diabe
#    Author profile link: Unknown
#
# 2  Author: Unknown, Unknown
#    publication Year: 1 Jun 2018
#    title: Adiposity and risk of ischaemic and haemorrhagic stroke in 0·5 million Chinese men and women: a prospective cohort study
#    Publication page link: https://pureportal.coventry.ac.uk/en/publications/adiposity-and-risk-of-ischaemic-and-haemorrhagic-stroke-in-05-mil
#    Author profile link: Unknown
